// %% [markdown]
// # Memory
//
// <div style="display: flex; justify-content: flex-start; gap: 10px;">
//   <img src="./assets/LC_Memory_after.png" alt="Image 2" style="width:300px; border:1px solid #ccc; border-radius:6px;">
// </div>
//
// Persisting messages, or 'agent state' between invocations of the agent.

// %% [markdown]
// First, let's connect to our SQLite database containing music store data.

// %%
import { SqlDatabase } from "@langchain/classic/sql_db";
import { DataSource } from "typeorm";

const datasource = new DataSource({
    type: "sqlite",
    database: "./Chinook.db", // Replace with the link to your database
});
const db = await SqlDatabase.fromDataSourceParams({
    appDataSource: datasource,
});

// %% [markdown]
// Define a context schema to hold customer information (first and last name) that will be available throughout the agent's execution.

// %%
import { z } from "zod";

const contextSchema = z.object({
    db: z.instanceof(SqlDatabase)
});
type Context = z.infer<typeof contextSchema>;

// %% [markdown]
// Create a tool to execute SQL queries. It supports named parameters (`:first`, `:last`) that get replaced with values from the runtime context.

// %%
import { tool, Runtime } from "langchain";

const executeSQL = tool(async ({ query }, runtime: Runtime<Context>) => {
    return await db.run(query);
}, {
    name: "execute_sql",
    description: "Execute a SQLite command and return results.",
    schema: z.object({
        query: z.string()
    })
});

// %% [markdown]
// Define the system prompt that instructs the agent how to interact with the database safely and use named parameters.

// %%
export const SYSTEM = `You are a careful SQLite analyst.

Rules:
- Think step-by-step.
- When you need data, call the tool \`execute_sql\` with ONE SELECT query.
- Read-only only; no INSERT/UPDATE/DELETE/ALTER/DROP/CREATE/REPLACE/TRUNCATE.
- Limit to 5 rows unless the user explicitly asks otherwise.
- If the tool returns 'Error:', revise the SQL and try again.
- Prefer explicit column lists; avoid SELECT *.`

// %% [markdown]
// Create the agent with our tools and system prompt. Note: **no checkpointer yet**, so the agent won't remember previous conversations.

// %%
import * as setup from "./setup.ts";
import { createAgent } from "langchain";

const agent = createAgent({
    model: "anthropic:claude-sonnet-4-5-20250929",
    tools: [executeSQL],
    systemPrompt: SYSTEM,
    contextSchema,
})

// %% [markdown]
// ## Repeated Queries

// %% [markdown]
// Ask about Frank Harris's last invoice. The agent successfully retrieves the information.

// %%
const stream = await agent.stream({
    messages: "This is Frank Harris, What was the total on my last invoice?",
}, {
    streamMode: "values",
    context: { db }
})

for await (const step of stream) {
    displayMessage(step.messages.at(-1))
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// This is Frank Harris, What was the total on my last invoice?
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "I'll help you find the total on your last invoice, Frank. Let me search for your information in the database."
//   },
//   {
//     type: "tool_use",
//     id: "toolu_01CnsRtfwyhpudX3kf6kZH7H",
//     name: "execute_sql",
//     input: { query: "SELECT name FROM sqlite_master WHERE type='table'" },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Album"},{"name":"Artist"},{"name":"Customer"},{"name":"Employee"},{"name":"Genre"},{"name":"Invoice"},{"name":"InvoiceLine"},{"name":"MediaType"},{"name":"Playlist"},{"name":"PlaylistTrack"},{"name":"Track"}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "tool_use",
//     id: "toolu_01Dccma2wBUwjehi4RdP5Wub",
//     name: "execute_sql",
//     input: {
//       query: "SELECT CustomerId, FirstName, LastName FROM Customer WHERE FirstName = 'Frank' AND LastName = 'Harris' LIMIT 5"
//     },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"CustomerId":16,"FirstName":"Frank","LastName":"Harris"}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "tool_use",
//     id: "toolu_012vqx8dAVpB3pDeaj7m9oJK",
//     name: "execute_sql",
//     input: {
//       query: "SELECT InvoiceId, InvoiceDate, Total FROM Invoice WHERE CustomerId = 16 ORDER BY InvoiceDate DESC LIMIT 1"
//     },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"InvoiceId":374,"InvoiceDate":"2013-07-04 00:00:00","Total":5.94}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// Hello Frank Harris! The total on your last invoice (Invoice #374 from July 4, 2013) was **$5.94**.

// %% [markdown]
// Now ask a follow-up question: "What were the titles?" Without memory, the agent has no idea what we're referring to and asks for clarification.

// %%
const stream = await agent.stream({
    messages: "What were the titles?",
}, {
    streamMode: "values",
    context: { db }
})

for await (const step of stream) {
    displayMessage(step.messages.at(-1))
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// What were the titles?
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "I need to see what data is available in the database first to understand what titles you're asking about.\n" +
//       "\n" +
//       "Let me check what tables exist:"
//   },
//   {
//     type: "tool_use",
//     id: "toolu_01NCPBUptZyj5gFpfwK3kbhR",
//     name: "execute_sql",
//     input: { query: "SELECT name FROM sqlite_master WHERE type='table'" },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Album"},{"name":"Artist"},{"name":"Customer"},{"name":"Employee"},{"name":"Genre"},{"name":"Invoice"},{"name":"InvoiceLine"},{"name":"MediaType"},{"name":"Playlist"},{"name":"PlaylistTrack"},{"name":"Track"}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "Now let me check if there's a table that contains titles. Let me look at a few likely tables:"
//   },
//   {
//     type: "tool_use",
//     id: "toolu_01564wQemNgUgBYwbCC1Hojd",
//     name: "execute_sql",
//     input: { query: "SELECT AlbumId, Title FROM Album LIMIT 5" },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"AlbumId":1,"Title":"For Those About To Rock We Salute You"},{"AlbumId":2,"Title":"Balls to the Wall"},{"AlbumId":3,"Title":"Restless and Wild"},{"AlbumId":4,"Title":"Let There Be Rock"},{"AlbumId":5,"Title":"Big Ones"}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// I found album titles in the database! However, since you didn't specify how many results you want, I've shown the first 5 albums. Here are the titles:
//
// 1. For Those About To Rock We Salute You
// 2. Balls to the Wall
// 3. Restless and Wild
// 4. Let There Be Rock
// 5. Big Ones
//
// Would you like to see:
// - All album titles in the database?
// - Titles from a specific artist?
// - Track titles instead?
// - Something else?

// %% [markdown]
// ## Add memory

// %% [markdown]
// Let's fix this by adding a checkpointer. The `MemorySaver` will store conversation history so the agent can remember context across turns.

// %%
import * as setup from "./setup.ts";
import { createAgent } from "langchain";
import { MemorySaver } from "@langchain/langgraph";

const checkpointer = new MemorySaver()
const agent = createAgent({
    model: "anthropic:claude-sonnet-4-5-20250929",
    tools: [executeSQL],
    systemPrompt: SYSTEM,
    contextSchema,
    checkpointer
})

// %% [markdown]
// Ask the same question again, but this time with a `thread_id` to track the conversation.

// %%
const stream = await agent.stream({
    messages: "This is Frank Harris, What was the total on my last invoice?",
}, {
    streamMode: "values",
    configurable: { thread_id: "1" },
    context: { db }
})

for await (const step of stream) {
    displayMessage(step.messages.at(-1))
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// This is Frank Harris, What was the total on my last invoice?
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "I'll help you find the total on your last invoice, Frank Harris. Let me search for that information.\n" +
//       "\n" +
//       "First, let me explore the database structure to find the relevant tables:"
//   },
//   {
//     type: "tool_use",
//     id: "toolu_01XhEf8ZuwTMPxrqE8KUAERd",
//     name: "execute_sql",
//     input: { query: "SELECT name FROM sqlite_master WHERE type='table'" },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"name":"Album"},{"name":"Artist"},{"name":"Customer"},{"name":"Employee"},{"name":"Genre"},{"name":"Invoice"},{"name":"InvoiceLine"},{"name":"MediaType"},{"name":"Playlist"},{"name":"PlaylistTrack"},{"name":"Track"}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   { type: "text", text: "Now let me find your customer record:" },
//   {
//     type: "tool_use",
//     id: "toolu_013ZfJX2HfTUWGLFvUorBWiK",
//     name: "execute_sql",
//     input: {
//       query: "SELECT CustomerId, FirstName, LastName FROM Customer WHERE FirstName = 'Frank' AND LastName = 'Harris'"
//     },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"CustomerId":16,"FirstName":"Frank","LastName":"Harris"}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   { type: "text", text: "Now let me get your most recent invoice:" },
//   {
//     type: "tool_use",
//     id: "toolu_01KzS9j7smX7baTk7wFCd66a",
//     name: "execute_sql",
//     input: {
//       query: "SELECT InvoiceId, InvoiceDate, Total FROM Invoice WHERE CustomerId = 16 ORDER BY InvoiceDate DESC LIMIT 1"
//     },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"InvoiceId":374,"InvoiceDate":"2013-07-04 00:00:00","Total":5.94}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// Hello Frank Harris! The total on your last invoice (Invoice #374 from July 4, 2013) was **$5.94**.

// %% [markdown]
// Now when we ask "What were the titles?", the agent remembers the previous question about the invoice and returns the track titles! 🎵

// %%
const stream = await agent.stream({
    messages: "What were the titles?",
}, {
    streamMode: "values",
    configurable: { thread_id: "1" },
    context: { db }
})

for await (const step of stream) {
    displayMessage(step.messages.at(-1))
}
// Out:
// ┌────────────────────────────────────────────────────────────┐
// │ 👤 HUMAN MESSAGE                                           │
// └────────────────────────────────────────────────────────────┘
// What were the titles?
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// [
//   {
//     type: "text",
//     text: "Let me find the titles of the items on that invoice:"
//   },
//   {
//     type: "tool_use",
//     id: "toolu_01CY9E9CBird7hyNU7QbG2tk",
//     name: "execute_sql",
//     input: {
//       query: "SELECT Track.Name, InvoiceLine.UnitPrice, InvoiceLine.Quantity FROM InvoiceLine JOIN Track ON InvoiceLine.TrackId = Track.TrackId WHERE InvoiceLine.InvoiceId = 374"
//     },
//     caller: { type: "direct" }
//   }
// ]
// ┌────────────────────────────────────────────────────────────┐
// │ 🔧 TOOL MESSAGE                                            │
// └────────────────────────────────────────────────────────────┘
// [{"Name":"Holier Than Thou","UnitPrice":0.99,"Quantity":1},{"Name":"Through The Never","UnitPrice":0.99,"Quantity":1},{"Name":"My Friend Of Misery","UnitPrice":0.99,"Quantity":1},{"Name":"The Wait","UnitPrice":0.99,"Quantity":1},{"Name":"Blitzkrieg","UnitPrice":0.99,"Quantity":1},{"Name":"So What","UnitPrice":0.99,"Quantity":1}]
// ┌────────────────────────────────────────────────────────────┐
// │ 🤖 AI MESSAGE                                              │
// └────────────────────────────────────────────────────────────┘
// Here are the titles on your invoice:
//
// 1. Holier Than Thou - $0.99
// 2. Through The Never - $0.99
// 3. My Friend Of Misery - $0.99
// 4. The Wait - $0.99
// 5. Blitzkrieg - $0.99
// 6. So What - $0.99
//
// All six tracks were $0.99 each, totaling $5.94.
